# %%
import os
from tools import *

# %%
base_path = "raw_data"
subjects = [f.split('_')[0] for f in os.listdir(f"{base_path}/labels") if f.endswith(".txt")]
print(len(subjects))
print(subjects)
# Out:
# 31
# ['1066528', '1360686', '1449548', '1455390', '1818471', '2598705', '2638030', '3509524', '3997827', '4018081', '4314139', '4426783', '46343', '5132496', '5383425', '5498603', '5797046', '6220552', '759667', '7749105', '781756', '8000685', '8173033', '8258170', '844359', '8530312', '8686948', '8692923', '9106476', '9618981', '9961348']

# %%
def load_subject_data(subject):
    motion = pd.read_csv(f"{base_path}/motion/{subject}_acceleration.txt", sep=" ", header=None,
                         names=["time", "x", "y", "z"])
    heart = pd.read_csv(f"{base_path}/heart_rate/{subject}_heartrate.txt", sep=",", header=None,
                        names=["time", "heart_rate"])
    labels = pd.read_csv(f"{base_path}/labels/{subject}_labeled_sleep.txt", sep=" ", header=None,
                         names=["time", "stage"])
    return motion, heart, labels

# %%
for subject in subjects:
    df = None
    print(subject)
    motion_uncropped, heart_uncropped, labels_uncropped = load_subject_data(subject)
    motion, heart, labels = crop_data(motion_uncropped, heart_uncropped, labels_uncropped)

    # jak dużo aktywności w danej sekundzie
    activity = build_activity_counts(motion)
    heart_rate = build_heart_rate(heart)

    # zaokrąglenie w dół do najbliższej wielokrotności 30 - do której epoki należy pomiar (pomiary w sekndach)
    motion_ids = motion["time"].apply(lambda x: x - np.mod(x, 30))
    heart_ids = heart["time"].apply(lambda x: x - np.mod(x, 30))

    valid_times = set(motion_ids) & set(heart_ids)
    valid_epochs = labels[(labels["time"].isin(valid_times)) & (labels["stage"] != -1)]["time"].tolist()

    rows = []
    for epoch in valid_epochs:
        rows.append({
            "second_of_sleep": epoch,
            "label": labels.loc[labels['time'] == epoch, "stage"].iloc[0],
            # jak dużo aktywności w przeciągu 15 sekund - wygładzenie gaussem
            "activity_count": smooth_gauss(get_window(activity, "activity", epoch)),
            # odchylenie standardowe wartości w oknie czasowym
            "heart_rate_std": np.std(get_window(heart_rate, "heart_rate", epoch)),
            # jak bardzo jest to senny czas dla organizmu
            "circadian_cycle": cosine_proxy(epoch - valid_epochs[0]),
            "hour_of_sleep": (epoch - valid_epochs[0]) / 3600.0
        })
    df = pd.DataFrame(rows)
    df.set_index('second_of_sleep', inplace=True)

    mapping = {0: 0, 1: 1, 2: 1, 3: 1, 4: 1, 5: 2}
    df["label"] = df["label"].map(mapping)

    df.to_pickle(f"datasets/data_{subject}.pkl")
# Out:
# 1066528
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0        0.000000        0.351612        -0.258819
# 30                   0        0.000000        0.336348        -0.260926
# 60                   0        0.000000        0.322797        -0.263031
# 90                   0        0.001274        0.310572        -0.265135
# 120                  0        0.009708        0.299694        -0.267238
# ...                ...             ...             ...              ...
# 25980                0        7.307716        0.640652        -0.836286
# 26010                0        6.556160        0.656672        -0.835088
# 26040                0        7.720901        0.664027        -0.833886
# 26070                0        8.198019        0.680921        -0.832680
# 27930                0        0.057462        0.283500        -0.750400
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 25980                 7.216667
# 26010                 7.225000
# 26040                 7.233333
# 26070                 7.241667
# 27930                 7.758333
#
# [818 rows x 5 columns]
# 1360686
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 1230                 0        2.023889        0.354599        -0.258819
# 1260                 0        1.483139        0.360025        -0.260926
# 1290                 0        1.075193        0.370624        -0.263031
# 1320                 0        0.787072        0.370765        -0.265135
# 1350                 0        0.587901        0.370664        -0.267238
# ...                ...             ...             ...              ...
# 28830                1        0.000000        0.294663        -0.766044
# 28860                1        0.000000        0.304188        -0.764640
# 28890                1        0.000000        0.310612        -0.763232
# 28920                1        0.000000        0.320519        -0.761821
# 28950                1        0.000000        0.332524        -0.760406
#
#                  hour_of_sleep
# second_of_sleep
# 1230                  0.000000
# 1260                  0.008333
# 1290                  0.016667
# 1320                  0.025000
# 1350                  0.033333
# ...                        ...
# 28830                 7.666667
# 28860                 7.675000
# 28890                 7.683333
# 28920                 7.691667
# 28950                 7.700000
#
# [925 rows x 5 columns]
# 1449548
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 330                  0       52.230259        0.623612        -0.258819
# 360                  0       58.011722        0.613273        -0.260926
# 390                  0       53.541114        0.621457        -0.263031
# 420                  0       41.284580        0.609565        -0.265135
# 450                  0       27.166058        0.606145        -0.267238
# ...                ...             ...             ...              ...
# 28770                0        0.000000        0.143829        -0.725374
# 28800                0        0.000000        0.145270        -0.723871
# 28830                0        0.000000        0.137757        -0.722364
# 28860                0        0.000000        0.137304        -0.720854
# 28890                0        0.000000        0.140066        -0.719340
#
#                  hour_of_sleep
# second_of_sleep
# 330                   0.000000
# 360                   0.008333
# 390                   0.016667
# 420                   0.025000
# 450                   0.033333
# ...                        ...
# 28770                 7.900000
# 28800                 7.908333
# 28830                 7.916667
# 28860                 7.925000
# 28890                 7.933333
#
# [885 rows x 5 columns]
# 1455390
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 1020                 0       76.144269        0.923841        -0.258819
# 1050                 0       64.048909        0.927949        -0.260926
# 1080                 0       39.660062        0.931663        -0.263031
# 1110                 0       18.086297        0.937193        -0.265135
# 1140                 0        6.061488        0.943779        -0.267238
# ...                ...             ...             ...              ...
# 29520                0        0.004567        0.341325        -0.722364
# 29550                1        0.014659        0.352830        -0.720854
# 29580                0        0.043077        0.366378        -0.719340
# 29610                0        0.115925        0.381931        -0.717823
# 29640                0        0.285819        0.399621        -0.716302
#
#                  hour_of_sleep
# second_of_sleep
# 1020                  0.000000
# 1050                  0.008333
# 1080                  0.016667
# 1110                  0.025000
# 1140                  0.033333
# ...                        ...
# 29520                 7.916667
# 29550                 7.925000
# 29580                 7.933333
# 29610                 7.941667
# 29640                 7.950000
#
# [954 rows x 5 columns]
# 1818471
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 600                  0       71.235697        1.128547        -0.258819
# 630                  0       68.869056        1.075000        -0.260926
# 660                  0       58.402439        1.011943        -0.263031
# 690                  0       39.812788        1.007286        -0.265135
# 720                  0       20.531556        1.015981        -0.267238
# ...                ...             ...             ...              ...
# 29190                1       12.935150        0.290610        -0.717823
# 29220                1       13.490637        0.289498        -0.716302
# 29250                1       10.375369        0.291825        -0.714778
# 29280                1        5.728127        0.298877        -0.713250
# 29310                1        2.981303        0.309321        -0.711720
#
#                  hour_of_sleep
# second_of_sleep
# 600                   0.000000
# 630                   0.008333
# 660                   0.016667
# 690                   0.025000
# 720                   0.033333
# ...                        ...
# 29190                 7.941667
# 29220                 7.950000
# 29250                 7.958333
# 29280                 7.966667
# 29310                 7.975000
#
# [958 rows x 5 columns]
# 2598705
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 780                  0       48.179190        0.823369        -0.258819
# 810                  0       32.317384        0.827015        -0.260926
# 840                  0       16.451124        0.829049        -0.263031
# 870                  0        7.621991        0.830607        -0.265135
# 900                  0        5.544550        0.832356        -0.267238
# ...                ...             ...             ...              ...
# 29250                1        0.000004        0.374989        -0.723871
# 29280                1        0.000017        0.223359        -0.722364
# 29310                1        0.000064        0.164888        -0.720854
# 29340                1        0.000216        0.142438        -0.719340
# 29370                2        0.000673        0.085737        -0.717823
#
#                  hour_of_sleep
# second_of_sleep
# 780                   0.000000
# 810                   0.008333
# 840                   0.016667
# 870                   0.025000
# 900                   0.033333
# ...                        ...
# 29250                 7.908333
# 29280                 7.916667
# 29310                 7.925000
# 29340                 7.933333
# 29370                 7.941667
#
# [851 rows x 5 columns]
# 2638030
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 390                  0       30.479317        0.497519        -0.258819
# 420                  0       22.362416        0.481205        -0.260926
# 450                  0       13.720652        0.476733        -0.263031
# 480                  0        7.715356        0.474023        -0.265135
# 510                  0        4.276042        0.467707        -0.267238
# ...                ...             ...             ...              ...
# 28680                2        0.023429        0.745670        -0.732840
# 28710                2        0.003114        0.748769        -0.731354
# 28740                2        0.000571        0.759595        -0.729864
# 28770                2        0.000161        0.760758        -0.728371
# 28800                2        0.000041        0.712101        -0.726874
#
#                  hour_of_sleep
# second_of_sleep
# 390                   0.000000
# 420                   0.008333
# 450                   0.016667
# 480                   0.025000
# 510                   0.033333
# ...                        ...
# 28680                 7.858333
# 28710                 7.866667
# 28740                 7.875000
# 28770                 7.883333
# 28800                 7.891667
#
# [948 rows x 5 columns]
# 3509524
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0        1.764820        0.301808        -0.258819
# 30                   0        1.114408        0.289450        -0.260926
# 60                   0        0.731338        0.281359        -0.263031
# 90                   0        0.582780        0.271712        -0.265135
# 120                  0        0.699814        0.262948        -0.267238
# ...                ...             ...             ...              ...
# 12330                1        0.000000        0.049876        -0.916188
# 12360                1        0.000000        0.051596        -0.917060
# 12390                1        0.000000        0.053521        -0.917928
# 12420                1        0.000000        0.055089        -0.918791
# 12450                1        0.000000        0.047804        -0.919650
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 12330                 3.425000
# 12360                 3.433333
# 12390                 3.441667
# 12420                 3.450000
# 12450                 3.458333
#
# [416 rows x 5 columns]
# 3997827
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 510                  0       22.841235        1.084562        -0.258819
# 540                  0       17.868049        1.023675        -0.260926
# 570                  0       13.470778        0.989099        -0.263031
# 600                  0       10.319538        1.079184        -0.265135
# 630                  0        7.936492        1.205840        -0.267238
# ...                ...             ...             ...              ...
# 29100                2        0.970397        0.942421        -0.717823
# 29130                2        0.478116        0.964117        -0.716302
# 29160                2        0.216666        0.987423        -0.714778
# 29190                2        0.093235        0.955440        -0.713250
# 29220                2        0.035344        0.843800        -0.711720
#
#                  hour_of_sleep
# second_of_sleep
# 510                   0.000000
# 540                   0.008333
# 570                   0.016667
# 600                   0.025000
# 630                   0.033333
# ...                        ...
# 29100                 7.941667
# 29130                 7.950000
# 29160                 7.958333
# 29190                 7.966667
# 29220                 7.975000
#
# [958 rows x 5 columns]
# 4018081
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       67.810196        2.502905        -0.258819
# 30                   0       50.746031        2.456665        -0.260926
# 60                   0       35.298794        2.396852        -0.263031
# 90                   0       22.746742        2.335059        -0.265135
# 120                  0       13.545580        2.279286        -0.267238
# ...                ...             ...             ...              ...
# 14820                0        0.005897        0.218755        -0.973379
# 14850                0        0.000511        0.200310        -0.973877
# 14880                0        0.000000        0.203944        -0.974370
# 14910                0        0.000000        0.222295        -0.974859
# 14940                0        0.000000        0.237913        -0.975342
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 14820                 4.116667
# 14850                 4.125000
# 14880                 4.133333
# 14910                 4.141667
# 14940                 4.150000
#
# [497 rows x 5 columns]
# 4314139
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 240                  0       57.137085        0.382818        -0.258819
# 270                  0       51.822825        0.383772        -0.260926
# 300                  0       40.930635        0.393443        -0.263031
# 330                  0       29.598152        0.410841        -0.265135
# 360                  0       26.736921        0.396342        -0.267238
# ...                ...             ...             ...              ...
# 28920                0       17.237251        0.781011        -0.713250
# 28950                0       24.211297        0.779927        -0.711720
# 28980                0       31.368540        0.767769        -0.710185
# 29010                0       37.528470        0.734691        -0.708648
# 29040                0       41.522606        0.694689        -0.707107
#
#                  hour_of_sleep
# second_of_sleep
# 240                   0.000000
# 270                   0.008333
# 300                   0.016667
# 330                   0.025000
# 360                   0.033333
# ...                        ...
# 28920                 7.966667
# 28950                 7.975000
# 28980                 7.983333
# 29010                 7.991667
# 29040                 8.000000
#
# [961 rows x 5 columns]
# 4426783
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0        0.790272        0.683797        -0.258819
# 30                   0        0.349145        0.671957        -0.260926
# 60                   0        0.141505        0.645540        -0.263031
# 90                   0        0.052581        0.628085        -0.265135
# 120                  0        0.017908        0.631312        -0.267238
# ...                ...             ...             ...              ...
# 29220                2        0.013997        0.555886        -0.685183
# 29250                2        0.005286        0.575591        -0.683592
# 29280                2        0.001272        0.573244        -0.681998
# 29310                2        0.000000        0.521167        -0.680401
# 29340                2        0.000000        0.464724        -0.678801
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 29220                 8.116667
# 29250                 8.125000
# 29280                 8.133333
# 29310                 8.141667
# 29340                 8.150000
#
# [979 rows x 5 columns]
# 46343
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 390                  0       38.635633        0.525158        -0.258819
# 420                  0       31.644878        0.512713        -0.260926
# 450                  0       22.574075        0.494949        -0.263031
# 480                  0       19.341328        0.486835        -0.265135
# 510                  0       21.958676        0.480185        -0.267238
# ...                ...             ...             ...              ...
# 16830                0        3.592399        0.799764        -0.993572
# 16860                0        4.114574        0.496622        -0.993816
# 16890                0        4.331797        0.331372        -0.994056
# 16920                0        4.188018        0.324850        -0.994291
# 16950                0        3.715011        0.307009        -0.994522
#
#                  hour_of_sleep
# second_of_sleep
# 390                   0.000000
# 420                   0.008333
# 450                   0.016667
# 480                   0.025000
# 510                   0.033333
# ...                        ...
# 16830                 4.566667
# 16860                 4.575000
# 16890                 4.583333
# 16920                 4.591667
# 16950                 4.600000
#
# [553 rows x 5 columns]
# 5132496
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       13.906072        0.921304        -0.258819
# 30                   0       16.131959        0.933931        -0.260926
# 60                   0       17.476923        0.939113        -0.263031
# 90                   0       17.554699        0.923408        -0.265135
# 120                  0       16.297847        0.896457        -0.267238
# ...                ...             ...             ...              ...
# 13770                1        0.000000        0.128762        -0.953059
# 13800                1        0.000000        0.131835        -0.953717
# 13830                1        0.000000        0.129114        -0.954371
# 13860                1        0.000000        0.119166        -0.955020
# 13890                1        0.000000        0.109435        -0.955665
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 13770                 3.825000
# 13800                 3.833333
# 13830                 3.841667
# 13860                 3.850000
# 13890                 3.858333
#
# [464 rows x 5 columns]
# 5383425
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       40.901720        0.399370        -0.258819
# 30                   0       36.170273        0.407915        -0.260926
# 60                   0       31.406462        0.413402        -0.263031
# 90                   0       27.204173        0.412853        -0.265135
# 120                  0       23.829672        0.405779        -0.267238
# ...                ...             ...             ...              ...
# 29160                1        0.000000        0.147918        -0.688355
# 29190                1        0.000000        0.124336        -0.686770
# 29220                1        0.000000        0.105239        -0.685183
# 29250                1        0.000000        0.098494        -0.683592
# 29280                1        0.000000        0.094487        -0.681998
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 29160                 8.100000
# 29190                 8.108333
# 29220                 8.116667
# 29250                 8.125000
# 29280                 8.133333
#
# [975 rows x 5 columns]
# 5498603
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 330                  0       48.584883        0.407120        -0.258819
# 360                  0       38.490807        0.379032        -0.260926
# 390                  0       23.178293        0.337057        -0.263031
# 420                  0       10.802165        0.318171        -0.265135
# 450                  0        3.970622        0.332484        -0.267238
# ...                ...             ...             ...              ...
# 22500                2        0.000000        0.298451        -0.954371
# 22530                2        0.000000        0.301064        -0.953717
# 22560                2        0.000000        0.302116        -0.953059
# 22590                2        0.000000        0.301216        -0.952396
# 22620                2        0.000000        0.304874        -0.951728
#
#                  hour_of_sleep
# second_of_sleep
# 330                   0.000000
# 360                   0.008333
# 390                   0.016667
# 420                   0.025000
# 450                   0.033333
# ...                        ...
# 22500                 6.158333
# 22530                 6.166667
# 22560                 6.175000
# 22590                 6.183333
# 22620                 6.191667
#
# [743 rows x 5 columns]
# 5797046
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 660                  0       12.976065        0.256838        -0.258819
# 690                  0       10.945971        0.268871        -0.260926
# 720                  0        6.558382        0.280335        -0.263031
# 750                  0        2.825493        0.293524        -0.265135
# 780                  0        1.100884        0.300140        -0.267238
# ...                ...             ...             ...              ...
# 28680                2        0.000000        0.635795        -0.746057
# 28710                2        0.000000        0.621279        -0.744603
# 28740                2        0.000000        0.573801        -0.743145
# 28770                2        0.000000        0.479433        -0.741683
# 28800                2        0.000000        0.361012        -0.740218
#
#                  hour_of_sleep
# second_of_sleep
# 660                   0.000000
# 690                   0.008333
# 720                   0.016667
# 750                   0.025000
# 780                   0.033333
# ...                        ...
# 28680                 7.783333
# 28710                 7.791667
# 28740                 7.800000
# 28770                 7.808333
# 28800                 7.816667
#
# [938 rows x 5 columns]
# 6220552
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 810                  0       28.549813        0.234768        -0.258819
# 840                  0       19.845822        0.217709        -0.260926
# 870                  0       15.655003        0.205887        -0.263031
# 900                  0       17.030868        0.196767        -0.265135
# 930                  0       19.015967        0.198119        -0.267238
# ...                ...             ...             ...              ...
# 29280                1        0.000000        0.491670        -0.723871
# 29310                1        0.000000        0.507556        -0.722364
# 29340                1        0.000000        0.498900        -0.720854
# 29370                1        0.000000        0.413220        -0.719340
# 29400                1        0.000000        0.400095        -0.717823
#
#                  hour_of_sleep
# second_of_sleep
# 810                   0.000000
# 840                   0.008333
# 870                   0.016667
# 900                   0.025000
# 930                   0.033333
# ...                        ...
# 29280                 7.908333
# 29310                 7.916667
# 29340                 7.925000
# 29370                 7.933333
# 29400                 7.941667
#
# [954 rows x 5 columns]
# 759667
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0        3.238086        0.719934        -0.258819
# 30                   0        1.794267        0.714014        -0.260926
# 60                   0        0.988202        0.721216        -0.263031
# 90                   0        0.555426        0.733691        -0.265135
# 120                  0        0.321730        0.742095        -0.267238
# ...                ...             ...             ...              ...
# 14070                2        0.288774        0.670514        -0.959437
# 14100                1        0.562050        0.693344        -0.960050
# 14130                0        1.015810        0.717100        -0.960658
# 14160                1        1.694526        0.742555        -0.961262
# 14190                1        2.608120        0.741841        -0.961861
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 14070                 3.908333
# 14100                 3.916667
# 14130                 3.925000
# 14160                 3.933333
# 14190                 3.941667
#
# [453 rows x 5 columns]
# 7749105
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 360                  0       40.979234        0.754158        -0.258819
# 390                  0       26.434285        0.752013        -0.260926
# 420                  0       13.475082        0.735853        -0.263031
# 450                  0        6.299199        0.670263        -0.265135
# 480                  0        3.897600        0.617367        -0.267238
# ...                ...             ...             ...              ...
# 3750                 1        0.000000        0.176078        -0.486717
# 3780                 1        0.000000        0.185928        -0.488621
# 3810                 1        0.000000        0.196428        -0.490524
# 3840                 1        0.000000        0.205592        -0.492424
# 3870                 1        0.000000        0.215502        -0.494321
#
#                  hour_of_sleep
# second_of_sleep
# 360                   0.000000
# 390                   0.008333
# 420                   0.016667
# 450                   0.025000
# 480                   0.033333
# ...                        ...
# 3750                  0.941667
# 3780                  0.950000
# 3810                  0.958333
# 3840                  0.966667
# 3870                  0.975000
#
# [118 rows x 5 columns]
# 781756
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0        6.682273        1.141522        -0.258819
# 30                   0        9.517897        1.116464        -0.260926
# 60                   0       12.869016        1.105013        -0.263031
# 90                   0       16.479339        1.091784        -0.265135
# 120                  0       20.035167        1.072036        -0.267238
# ...                ...             ...             ...              ...
# 29250                2        0.593766        0.598884        -0.683592
# 29280                2        0.978960        0.493052        -0.681998
# 29310                2        1.572836        0.361891        -0.680401
# 29340                2        2.431683        0.260648        -0.678801
# 29370                2        3.569238        0.214076        -0.677197
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 29250                 8.125000
# 29280                 8.133333
# 29310                 8.141667
# 29340                 8.150000
# 29370                 8.158333
#
# [978 rows x 5 columns]
# 8000685
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 150                  0       37.548481        0.497154        -0.258819
# 180                  0       29.507980        0.487811        -0.260926
# 210                  0       25.302715        0.479836        -0.263031
# 240                  0       24.046132        0.471904        -0.265135
# 270                  0       24.249261        0.465606        -0.267238
# ...                ...             ...             ...              ...
# 28740                1        5.612770        0.506803        -0.717823
# 28770                1        5.646589        0.428180        -0.716302
# 28800                0        6.630968        0.398619        -0.714778
# 28830                1        8.233074        0.405568        -0.713250
# 28860                1        9.980610        0.421024        -0.711720
#
#                  hour_of_sleep
# second_of_sleep
# 150                   0.000000
# 180                   0.008333
# 210                   0.016667
# 240                   0.025000
# 270                   0.033333
# ...                        ...
# 28740                 7.941667
# 28770                 7.950000
# 28800                 7.958333
# 28830                 7.966667
# 28860                 7.975000
#
# [950 rows x 5 columns]
# 8173033
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 840                  0       78.220132        0.837231        -0.258819
# 870                  0       37.423896        0.862019        -0.260926
# 900                  0       23.932318        0.900032        -0.263031
# 930                  0       31.367710        0.935592        -0.265135
# 960                  0       48.646857        0.933912        -0.267238
# ...                ...             ...             ...              ...
# 29340                1        0.795019        0.300126        -0.722364
# 29370                1        1.403158        0.301119        -0.720854
# 29400                1        2.270653        0.296311        -0.719340
# 29430                1        3.369402        0.300172        -0.717823
# 29460                1        4.585636        0.311056        -0.716302
#
#                  hour_of_sleep
# second_of_sleep
# 840                   0.000000
# 870                   0.008333
# 900                   0.016667
# 930                   0.025000
# 960                   0.033333
# ...                        ...
# 29340                 7.916667
# 29370                 7.925000
# 29400                 7.933333
# 29430                 7.941667
# 29460                 7.950000
#
# [955 rows x 5 columns]
# 8258170
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       13.192067        0.264996        -0.258819
# 30                   0        8.976183        0.291446        -0.260926
# 60                   0        5.679012        0.344662        -0.263031
# 90                   0        3.339487        0.354096        -0.265135
# 120                  0        1.829007        0.345846        -0.267238
# ...                ...             ...             ...              ...
# 28980                2        2.528643        0.141498        -0.697790
# 29010                2        2.316698        0.141674        -0.696226
# 29040                2        1.942606        0.144177        -0.694658
# 29070                2        1.491098        0.131666        -0.693087
# 29100                2        1.048141        0.094252        -0.691513
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 28980                 8.050000
# 29010                 8.058333
# 29040                 8.066667
# 29070                 8.075000
# 29100                 8.083333
#
# [971 rows x 5 columns]
# 844359
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 1350                 0        2.174234        0.290980        -0.258819
# 1380                 0        0.590153        0.294554        -0.260926
# 1410                 0        0.113208        0.295112        -0.263031
# 1440                 0        0.015343        0.294559        -0.265135
# 1470                 0        0.001468        0.294707        -0.267238
# ...                ...             ...             ...              ...
# 28080                2       18.989684        0.373254        -0.805153
# 28110                0       27.322587        0.426159        -0.803857
# 28140                0       29.602491        0.448575        -0.802557
# 28170                0       28.851808        0.457045        -0.801254
# 28200                0       26.601220        0.460139        -0.799947
#
#                  hour_of_sleep
# second_of_sleep
# 1350                  0.000000
# 1380                  0.008333
# 1410                  0.016667
# 1440                  0.025000
# 1470                  0.033333
# ...                        ...
# 28080                 7.425000
# 28110                 7.433333
# 28140                 7.441667
# 28170                 7.450000
# 28200                 7.458333
#
# [896 rows x 5 columns]
# 8530312
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 480                  0       53.632191        0.600555        -0.258819
# 510                  0       53.228490        0.599168        -0.260926
# 540                  0       38.473611        0.596102        -0.263031
# 570                  0       20.114972        0.595949        -0.265135
# 600                  0        7.609411        0.594941        -0.267238
# ...                ...             ...             ...              ...
# 28800                1        0.814323        0.866669        -0.731354
# 28830                1        1.221465        0.881795        -0.729864
# 28860                0        1.744115        0.864539        -0.728371
# 28890                1        2.318448        0.841232        -0.726874
# 28920                1        2.857167        0.832966        -0.725374
#
#                  hour_of_sleep
# second_of_sleep
# 480                   0.000000
# 510                   0.008333
# 540                   0.016667
# 570                   0.025000
# 600                   0.033333
# ...                        ...
# 28800                 7.866667
# 28830                 7.875000
# 28860                 7.883333
# 28890                 7.891667
# 28920                 7.900000
#
# [888 rows x 5 columns]
# 8686948
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 450                  0       34.718938        1.156375        -0.258819
# 480                  0       14.685371        1.169434        -0.260926
# 510                  0        5.292484        1.136559        -0.263031
# 540                  0        2.729662        1.063707        -0.265135
# 570                  0        2.654953        1.014273        -0.267238
# ...                ...             ...             ...              ...
# 28950                1        0.000000        0.100380        -0.722364
# 28980                1        0.000000        0.099652        -0.720854
# 29010                1        0.000000        0.095117        -0.719340
# 29040                1        0.000000        0.090239        -0.717823
# 29070                1        0.000000        0.082090        -0.716302
#
#                  hour_of_sleep
# second_of_sleep
# 450                   0.000000
# 480                   0.008333
# 510                   0.016667
# 540                   0.025000
# 570                   0.033333
# ...                        ...
# 28950                 7.916667
# 28980                 7.925000
# 29010                 7.933333
# 29040                 7.941667
# 29070                 7.950000
#
# [955 rows x 5 columns]
# 8692923
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 870                  0        8.400208        0.370406        -0.258819
# 900                  0        4.367169        0.309038        -0.260926
# 930                  0        1.618323        0.302790        -0.263031
# 960                  0        0.425969        0.284633        -0.265135
# 990                  0        0.079482        0.282332        -0.267238
# ...                ...             ...             ...              ...
# 28770                2        0.000000        0.130539        -0.751840
# 28800                2        0.000000        0.134234        -0.750400
# 28830                2        0.000000        0.138746        -0.748956
# 28860                2        0.000000        0.142537        -0.747508
# 28890                2        0.000000        0.148913        -0.746057
#
#                  hour_of_sleep
# second_of_sleep
# 870                   0.000000
# 900                   0.008333
# 930                   0.016667
# 960                   0.025000
# 990                   0.033333
# ...                        ...
# 28770                 7.750000
# 28800                 7.758333
# 28830                 7.766667
# 28860                 7.775000
# 28890                 7.783333
#
# [935 rows x 5 columns]
# 9106476
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 420                  0        0.788455        0.378021        -0.258819
# 450                  0        0.150479        0.391188        -0.260926
# 480                  0        0.020528        0.391946        -0.263031
# 510                  0        0.001989        0.397845        -0.265135
# 540                  1        0.000136        0.415281        -0.267238
# ...                ...             ...             ...              ...
# 29070                1        0.019231        0.254662        -0.714778
# 29100                0        0.003842        0.263265        -0.713250
# 29130                1        0.000000        0.262906        -0.711720
# 29160                0        0.000000        0.242335        -0.710185
# 29190                1        0.000000        0.221510        -0.708648
#
#                  hour_of_sleep
# second_of_sleep
# 420                   0.000000
# 450                   0.008333
# 480                   0.016667
# 510                   0.025000
# 540                   0.033333
# ...                        ...
# 29070                 7.958333
# 29100                 7.966667
# 29130                 7.975000
# 29160                 7.983333
# 29190                 7.991667
#
# [960 rows x 5 columns]
# 9618981
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       54.717692        1.239545        -0.258819
# 30                   0       53.135574        1.205447        -0.260926
# 60                   0       48.322814        1.167899        -0.263031
# 90                   0       41.566724        1.140277        -0.265135
# 120                  0       34.378405        1.125086        -0.267238
# ...                ...             ...             ...              ...
# 28170                1        0.000000        0.092931        -0.738749
# 28200                1        0.000000        0.085228        -0.737277
# 28230                1        0.000000        0.083309        -0.735802
# 28260                1        0.000000        0.084305        -0.734323
# 28290                1        0.000000        0.085546        -0.732840
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 28170                 7.825000
# 28200                 7.833333
# 28230                 7.841667
# 28260                 7.850000
# 28290                 7.858333
#
# [944 rows x 5 columns]
# 9961348
#                  label  activity_count  heart_rate_std  circadian_cycle  \
# second_of_sleep
# 0                    0       11.040130        0.433994        -0.258819
# 30                   0        7.561047        0.415026        -0.260926
# 60                   0        5.831469        0.399333        -0.263031
# 90                   0        5.829329        0.388220        -0.265135
# 120                  0        7.365949        0.375806        -0.267238
# ...                ...             ...             ...              ...
# 21420                0       39.463964        1.354808        -0.969231
# 21450                0       45.298359        1.305649        -0.968692
# 21480                0       49.129194        1.256232        -0.968148
# 21510                0       50.419222        1.257577        -0.967599
# 21540                0       49.070902        1.309048        -0.967046
#
#                  hour_of_sleep
# second_of_sleep
# 0                     0.000000
# 30                    0.008333
# 60                    0.016667
# 90                    0.025000
# 120                   0.033333
# ...                        ...
# 21420                 5.950000
# 21450                 5.958333
# 21480                 5.966667
# 21510                 5.975000
# 21540                 5.983333
#
# [712 rows x 5 columns]
